# %% [markdown]
# Introducción a la Criptografía y a la Seguridad de la información
#
# Juan Carlos Garavito Higuera

# %%
def caesar_cipher(text, shift, encrypt=True):
    result = ''
    for char in text:
        if char.isalpha():
            # Determine whether to encrypt or decrypt based on the 'encrypt' parameter
            factor = 1 if encrypt else -1
            # Shift the character by the specified amount
            shifted_char = chr((ord(char) - ord('A' if char.isupper() else 'a') + factor * shift) % 26 + ord('A' if char.isupper() else 'a'))
            result += shifted_char
        else:
            # Leave non-alphabetic characters unchanged
            result += char
    return result

# %%
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Caesar's ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
plain_text = "see you in two long weeks dearest friend"
shift = 4
encrypted = caesar_cipher(plain_text, shift, encrypt=True)
decrypted = caesar_cipher(encrypted, shift, encrypt=False)
print("PlainText: "+plain_text)
print("Encrypted: "+encrypted)
print("Decrypted: "+decrypted)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Caesar's ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# PlainText: see you in two long weeks dearest friend
# Encrypted: wii csy mr xas psrk aiiow hieviwx jvmirh
# Decrypted: see you in two long weeks dearest friend

# %%
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Caesar's ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
plain_text = "UNSECURE LAB"
shift = 6
encrypted = caesar_cipher(plain_text, shift, encrypt=True)
decrypted = caesar_cipher(encrypted, shift, encrypt=False)
print("PlainText: "+plain_text)
print("Encrypted: "+encrypted)
print("Decrypted: "+decrypted)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Caesar's ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# PlainText: UNSECURE LAB
# Encrypted: ATYKIAXK RGH
# Decrypted: UNSECURE LAB
